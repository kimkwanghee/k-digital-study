# %%
import pandas as pd

# %%
wine_red=pd.read_csv('winequality-red.csv',sep=';') #header=0 1행이 칼럼 이름일때 사용
wine_red['type']='red'
wine_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# 2      9.8        5  red
# 3      9.8        6  red
# 4      9.4        5  red

# %%
wine_white=pd.read_csv('winequality-white.csv',sep=';')
wine_white['type']='white'
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality   type
# 0      8.8        6  white
# 1      9.5        6  white
# 2     10.1        6  white
# 3      9.9        6  white
# 4      9.9        6  white

# %%
wine=pd.concat([wine_white,wine_red])
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality   type
# 0         8.8        6  white
# 1         9.5        6  white
# 2        10.1        6  white
# 3         9.9        6  white
# 4         9.9        6  white
# ...       ...      ...    ...
# 1594     10.5        5    red
# 1595     11.2        6    red
# 1596     11.0        6    red
# 1597     10.2        5    red
# 1598     11.0        6    red
#
# [6497 rows x 13 columns]

# %%
wine.columns=wine.columns.str.replace(' ','_')   #작업처리 실수를 줄여줌  
#str을 붙여주어야 컬럼의 문자열을 대상으로 대체 
#wine.columns까지는 인덱스가 객체 
wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality   type
# 0         8.8        6  white
# 1         9.5        6  white
# 2        10.1        6  white
# 3         9.9        6  white
# 4         9.9        6  white
# ...       ...      ...    ...
# 1594     10.5        5    red
# 1595     11.2        6    red
# 1596     11.0        6    red
# 1597     10.2        5    red
# 1598     11.0        6    red
#
# [6497 rows x 13 columns]

# %%
wine.describe() #수치형 변수의 요약통계 출력
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
wine.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
wine['quality'].describe() # 품질 컬럼의 요약통계
# Out:
# count    6497.000000
# mean        5.818378
# std         0.873255
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %%
import numpy as np
wine_unique=wine['quality'].unique()
np.sort(wine_unique)
# Out:
# array([3, 4, 5, 6, 7, 8, 9], dtype=int64)

# %%
wine['quality'].value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality   type
# 0      8.8        6  white
# 1      9.5        6  white
# 2     10.1        6  white
# 3      9.9        6  white
# 4      9.9        6  white

# %%
wine.groupby('type')['quality'].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
wine.groupby('type')['quality'].quantile([0,0.25,0.5,0.75,1])
# Out:
# type
# red    0.00    3.0
#        0.25    5.0
#        0.50    6.0
#        0.75    6.0
#        1.00    8.0
# white  0.00    3.0
#        0.25    5.0
#        0.50    6.0
#        0.75    6.0
#        1.00    9.0
# Name: quality, dtype: float64

# %%
wine.groupby(['type','volatile_acidity'])['quality'].describe()
# Out:
#                         count  mean       std  min   25%  50%   75%  max
# type  volatile_acidity
# red   0.120               3.0   7.0  0.000000  7.0  7.00  7.0  7.00  7.0
#       0.160               2.0   6.0  0.000000  6.0  6.00  6.0  6.00  6.0
#       0.180              10.0   5.9  0.567646  5.0  6.00  6.0  6.00  7.0
#       0.190               2.0   5.5  0.707107  5.0  5.25  5.5  5.75  6.0
#       0.200               3.0   6.0  1.000000  5.0  5.50  6.0  6.50  7.0
# ...                       ...   ...       ...  ...   ...  ...   ...  ...
# white 0.910               1.0   4.0       NaN  4.0  4.00  4.0  4.00  4.0
#       0.930               1.0   4.0       NaN  4.0  4.00  4.0  4.00  4.0
#       0.965               1.0   6.0       NaN  6.0  6.00  6.0  6.00  6.0
#       1.005               1.0   4.0       NaN  4.0  4.00  4.0  4.00  4.0
#       1.100               1.0   4.0       NaN  4.0  4.00  4.0  4.00  4.0
#
# [268 rows x 8 columns]

# %%
wine.groupby('type')['quality'].quantile([0,0.25,0.5,0.75,1]).unstack('type')   #
# Out:
# type  red  white
# 0.00  3.0    3.0
# 0.25  5.0    5.0
# 0.50  6.0    6.0
# 0.75  6.0    6.0
# 1.00  8.0    9.0

# %%
wine['type']=='red'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594     True
# 1595     True
# 1596     True
# 1597     True
# 1598     True
# Name: type, Length: 6497, dtype: bool

# %%
wine[wine['type']=='red']
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality type
# 0         9.4        5  red
# 1         9.8        5  red
# 2         9.8        5  red
# 3         9.8        6  red
# 4         9.4        5  red
# ...       ...      ...  ...
# 1594     10.5        5  red
# 1595     11.2        6  red
# 1596     11.0        6  red
# 1597     10.2        5  red
# 1598     11.0        6  red
#
# [1599 rows x 13 columns]

# %%
wine[wine['type']=='red']['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
red_q=wine[wine['type']=='red']['quality']
white_q=wine[wine['type']=='white']['quality']

import seaborn as sns
import  matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
sns.distplot(red_q,norm_hist=True,kde=False,color='red',label='red wine')    #kde=커널밀도함수
sns.distplot(white_q,norm_hist=True,kde=False,color='yellow',label='white wine') 
 #kde는 밀도함수 
plt.title('quality wine')
plt.xlabel('quality')
plt.ylabel('density')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wine.groupby('type')['quality'].aggregate(['std','mean'])
# Out:
#             std      mean
# type
# red    0.807569  5.636023
# white  0.885639  5.877909

# %%
import statsmodels.api as sm

# %%
t_stat,p_value,df=sm.stats.ttest_ind(red_q,white_q)

't_stat:{:3f},p-value{:4f}'.format(t_stat,p_value)
# Out:
# 't_stat:-9.685650,p-value0.000000'

# %%
df
# Out:
# 6495.0

# %%
wine_corr=wine.corr()
wine_corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity              -0.111981   0.298195            -0.282735
# volatile_acidity           -0.196011   0.377124            -0.352557
# citric_acid                 0.142451   0.038998             0.133126
# residual_sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free_sulfur_dioxide         0.402871  -0.195045             1.000000
# total_sulfur_dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile_acidity                 -0.414476  0.271296  0.261454   0.225984
# citric_acid                       0.195242  0.096154 -0.329808   0.056197
# residual_sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free_sulfur_dioxide               0.720934  0.025717 -0.145854  -0.188457
# total_sulfur_dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
#
#                        alcohol   quality
# fixed_acidity        -0.095452 -0.076743
# volatile_acidity     -0.037640 -0.265699
# citric_acid          -0.010493  0.085532
# residual_sugar       -0.359415 -0.036980
# chlorides            -0.256916 -0.200666
# free_sulfur_dioxide  -0.179838  0.055463
# total_sulfur_dioxide -0.265740 -0.041385
# density              -0.686745 -0.305858
# pH                    0.121248  0.019506
# sulphates            -0.003029  0.038485
# alcohol               1.000000  0.444319
# quality               0.444319  1.000000

# %%
wine_corr[wine_corr['quality']>=0]['quality']
# Out:
# citric_acid            0.085532
# free_sulfur_dioxide    0.055463
# pH                     0.019506
# sulphates              0.038485
# alcohol                0.444319
# quality                1.000000
# Name: quality, dtype: float64

# %%
wine_corr[wine_corr['quality']<0]['quality']
# Out:
# fixed_acidity          -0.076743
# volatile_acidity       -0.265699
# residual_sugar         -0.036980
# chlorides              -0.200666
# total_sulfur_dioxide   -0.041385
# density                -0.305858
# Name: quality, dtype: float64

# %%
red_sample=wine[wine['type']=='red']
white_sample=wine[wine['type']=='white']
red_sample
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality type
# 0         9.4        5  red
# 1         9.8        5  red
# 2         9.8        5  red
# 3         9.8        6  red
# 4         9.4        5  red
# ...       ...      ...  ...
# 1594     10.5        5  red
# 1595     11.2        6  red
# 1596     11.0        6  red
# 1597     10.2        5  red
# 1598     11.0        6  red
#
# [1599 rows x 13 columns]

# %%
red_idx=np.random.choice(red_sample.index,replace=True,size=200)
white_idx=np.random.choice(white_sample.index,replace=True,size=200)

# %%
wine_sample=red_sample.loc[red_idx].append(white_sample.loc[white_idx])

# %%
wine_sample
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 992             6.5              0.40         0.10             2.0      0.076
# 1184            6.7              0.64         0.23             2.1      0.080
# 593             9.9              0.49         0.58             3.5      0.094
# 1274            7.8              0.58         0.13             2.1      0.102
# 1253            7.9              0.66         0.00             1.4      0.096
# ...             ...               ...          ...             ...        ...
# 1539            7.3              0.26         0.49             5.0      0.028
# 1352            5.7              0.21         0.24             2.3      0.047
# 1110            7.2              0.37         0.15             2.0      0.029
# 186             6.7              0.24         0.41             9.4      0.040
# 3439            6.7              0.40         0.22             8.8      0.052
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 992                  30.0                  47.0  0.99554  3.36       0.48
# 1184                 11.0                 119.0  0.99538  3.36       0.70
# 593                   9.0                  43.0  1.00040  3.29       0.58
# 1274                 17.0                  36.0  0.99440  3.24       0.53
# 1253                  6.0                  13.0  0.99569  3.43       0.58
# ...                   ...                   ...      ...   ...        ...
# 1539                 32.0                 107.0  0.99360  3.24       0.54
# 1352                 60.0                 189.0  0.99500  3.65       0.72
# 1110                 27.0                  87.0  0.99030  3.30       0.59
# 186                  49.0                 166.0  0.99540  3.12       0.61
# 3439                 24.0                 113.0  0.99576  3.22       0.45
#
#       alcohol  quality   type
# 992       9.4        6    red
# 1184     10.9        5    red
# 593       9.0        5    red
# 1274     11.2        6    red
# 1253      9.5        5    red
# ...       ...      ...    ...
# 1539     10.8        6  white
# 1352     10.1        6  white
# 1110     12.6        7  white
# 186       9.9        6  white
# 3439      9.4        5  white
#
# [400 rows x 13 columns]

# %%
sns.set_style('dark')
sns.pairplot(wine_sample,vars=['quality','alcohol','residual_sugar'],kind='reg',plot_kws={'ci':False,'x_jitter':0.25,'y_jitter':0.25},
             diag_kind='hist',diag_kws={'bins':10,'alpha':1},hue='type',palette=dict(red='red',white='blue',markers={'o','s'})
            )
#vars=컬럼명  hue=type -> 타입별 색상 다르게 , diag_kind='hist' 각 변수별 히스토그램

# %% [markdown]
# ## 와인 데이터 선형회귀모델 적용

# %%
wine_red=pd.read_csv('winequality-red.csv',sep=';') #header=0 1행이 칼럼 이름일때 사용
wine_red['type']='red'

wine_white=pd.read_csv('winequality-white.csv',sep=';')
wine_white['type']='white'

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True,normalize=True) #절편값과 정규화 설정  -> 데이터, 정확도에 따라 설정 -> 
model
# Out:
# LinearRegression(normalize=True)

# %%
x=wine.drop(['type','quality'],axis=1)
x.shape

y=wine['quality']   
y.shape
# Out:
# (6497,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(x,y,random_state=1)
x_train.shape
# Out:
# (4872, 11)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
model.coef_
# Out:
# array([ 7.91343341e-02, -1.35396336e+00, -2.02681295e-01,  4.50371632e-02,
#        -4.38852980e-01,  5.24781751e-03, -2.32926031e-03, -5.73863038e+01,
#         4.52409324e-01,  7.61951539e-01,  2.59739752e-01])

# %%
model.intercept_
# Out:
# 58.156308300986765

# %%
newdata=np.array([6.3,0.3,0.34,1.6,0.049,14,132,0.996,3.3,0.49,9.5])

# %%
len(newdata)
# Out:
# 11

# %%
model.predict(np.reshape(newdata,(1,11)))  #데이터 1건을 이용하여 품질 예측
# Out:
# array([5.17339282])

# %%
y_pred=model.predict(x_test)   #데이터 셋 예측 
y_pred.shape
# Out:
# (1625,)

# %%
def rmse(y_real,y_pred):
    return np.sqrt(np.mean(y_real-y_pred)**2)

# %%
from sklearn.metrics import mean_squared_error
np.round(np.sqrt(mean_squared_error(y_test,y_pred)),2)
# Out:
# 0.72

# %%
y_pred.shape
# Out:
# (1625,)

# %%
x_test
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3772            6.3              0.24         0.29            13.7      0.035
# 1111            5.4              0.42         0.27             2.0      0.092
# 3464            6.9              0.29         0.41             7.8      0.046
# 1518            8.4              0.23         0.49             7.8      0.035
# 3761            6.1              0.17         0.28             2.5      0.028
# ...             ...               ...          ...             ...        ...
# 4276            5.2              0.31         0.20             2.4      0.027
# 384             7.7              0.51         0.28             2.1      0.087
# 3854            5.9              0.12         0.27             4.8      0.030
# 3358            6.7              0.36         0.28             8.3      0.034
# 968             9.0              0.40         0.43             2.4      0.068
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 1111                 23.0                  55.0  0.99471  3.78       0.64
# 3464                 52.0                 171.0  0.99537  3.12       0.51
# 1518                 22.0                  95.0  0.99350  3.04       0.34
# 3761                 22.0                  98.0  0.99072  3.16       0.37
# ...                   ...                   ...      ...   ...        ...
# 4276                 27.0                 117.0  0.98886  3.56       0.45
# 384                  23.0                  54.0  0.99800  3.42       0.74
# 3854                 40.0                 110.0  0.99226  3.55       0.68
# 3358                 29.0                  81.0  0.99151  2.96       0.39
# 968                  29.0                  46.0  0.99430  3.20       0.60
#
#       alcohol
# 3772     10.6
# 1111     12.3
# 3464      9.6
# 1518     12.0
# 3761     11.1
# ...       ...
# 4276     13.0
# 384       9.2
# 3854     12.1
# 3358     12.5
# 968      12.2
#
# [1625 rows x 11 columns]

# %%
wine_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality type
# 0         9.4        5  red
# 1         9.8        5  red
# 2         9.8        5  red
# 3         9.8        6  red
# 4         9.4        5  red
# ...       ...      ...  ...
# 1594     10.5        5  red
# 1595     11.2        6  red
# 1596     11.0        6  red
# 1597     10.2        5  red
# 1598     11.0        6  red
#
# [1599 rows x 13 columns]

# %% [markdown]
# ### 규제가 있는 선형모델

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
model=Ridge(alpha=1) 
model.fit(x_train,y_train)
y_ped=model.predict(x_test)
np.round(np.sqrt(mean_squared_error(y_test,y_pred)),2)
# Out:
# 0.86

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
model=Lasso(alpha=0.5) 
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
np.round(np.sqrt(mean_squared_error(y_test,y_pred)),2)
# Out:
# 0.86
